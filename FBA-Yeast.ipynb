# %% [markdown]
# ファイル一覧を確認する

# %%
ls
# Out:
# FBA-Yeast.ipynb                 iMM904Test.txt
# iMM904_181029aminoacid_def.txt  pyfba181121forSuntory.py
# iMM904_181029aminoacid.txt      simulation_suntory181028.py
# iMM904_181029_def.txt           simulation_suntory181029aminoacid.py
# iMM904_181029.txt               simulation_suntory181029.py
# iMM904_181030aminoacid_def.txt  Untitled.ipynb
# iMM904_181030aminoacid.txt

# %% [markdown]
# モデル定義の読み込み

# %%
import re, csv
import pulp

class MetabolicModel:
    def __init__(self, deffilename, modelfilename, mode = "normal"):
        format = "text"
        output = "normal"

        self.separator = {}
        self.constraint = {}
        self.optstep = {}
        self.inconstant = {}
        self.inconstant_array = []
        self.inconstant_onlyincrease = {}
        self.metabolites = {}
        self.reactions = {}
        self.reactionid_array = []
        self.maboliteid_array = []
        with open(deffilename, 'r') as f:
            if format == "text":
                reader = csv.reader(f, delimiter='\t')
            elif format == "csv":
                reader = csv.reader(f, dialect='excel')
            else:
                print("Unknown format!")
                f.close()
                return False

            for i, row in enumerate(reader):

                if len(row) == 0:
                    continue
                if "#" == row[0][0]:
                    continue
                row = [item for item in row if "#" not in item]
                # Remove '' from row
                row = list(filter(lambda s:s != '', row))

                if len(row) < 1:
                    continue
                row0 = row[0].replace(" ", "")
                if row0 == "separator_reversible":
                    separator_reversible = row[1]
                    separator_reversible = re.sub(r'^\s+',"",separator_reversible)
                    separator_reversible = re.sub(r'\s+$',"",separator_reversible)
                    self.separator["reversible"] = separator_reversible
                    continue
                if row0 == "separator_onedirection":
                    separator_onedirection = row[1]
                    separator_onedirection = re.sub(r'^\s+',"",separator_onedirection)
                    separator_onedirection = re.sub(r'\s+$',"",separator_onedirection)
                    self.separator["onedirection"] = separator_onedirection
                    continue
                if row0 == "separator_plus":
                    separator_plus = row[1]
                    separator_plus = re.sub(r'^\s+',"",separator_plus)
                    separator_plus = re.sub(r'\s+$',"",separator_plus)
                    self.separator["plus"] = separator_plus
                    continue
                if row0 == "optstep":
                    optstep = row[1]
                    optstep = re.sub(r'^\s+',"",optstep)
                    optstep = re.sub(r'\s+$',"",optstep)
                    optstep = self.check_reactionname(optstep)
                    if len(row) > 3:
                        self.optstep[optstep] = float(row[2])
                    else:
                        self.optstep[optstep] = 1.0


                    continue
                if row0 == "constraint":
                    temp = re.split(r'\s+\=\s+',row[1])
                    reaction = temp[0]
                    value = temp[1]
                    reaction = re.sub(r'^\s+',"",reaction)
                    reaction = re.sub(r'\s+$',"",reaction)
                    reaction = self.check_reactionname(reaction)
                    self.constraint[reaction] = value
                    continue

                if row0 == "inconstant_start":
                    mode = "inconstant"
                    continue
                if row0 == "inconstant_end":
                    mode = "normal"
                    continue
                if row0 == "inconstant_onlyincrease_start":
                    mode = "inconstant_onlyincrease"
                    continue
                if row0 == "inconstant_onlyincrease_end":
                    mode = "normal"
                    continue

                if mode == "inconstant":
                    if output == "debug":
                        print(row)
                    if len(row) < 1:
                        continue
                    rid = row[0].replace(" ", "")
                    rid = self.check_metabolitename(rid)
                    if rid == "":
                        continue

                    self.inconstant[rid] = 1
                    self.inconstant_array.append(rid)
                if mode == "inconstant_onlyincrease":
                    if output == "debug":
                        print(row)
                    if len(row) < 1:
                        continue
                    rid = row[0].replace(" ", "")
                    if rid == "":
                        continue
                    rid = re.sub(r'\_',"",rid)
                    rid = self.check_metabolitename(rid)
                    self.inconstant_onlyincrease[rid] = 1

        #
        #化合物名を収集する。
        #
        reactionid = 0

        with open(modelfilename, 'r') as f:
            if format == "text":
                reader = csv.reader(f, delimiter='\t')
            elif format == "csv":
                reader = csv.reader(f, dialect='excel')
            else:
                print("Unknown format!")
                f.close()
                return False

            for i, row in enumerate(reader):
                if len(row) < 6:
                    continue
                rid = row[0].replace('"', "")		#ID
                rid = self.check_reactionname(rid)


                reaction = row[5].replace('"', "") #	反応式
                flag = row[1].replace('"', "")
                group = row[2].replace('"', "")	#反応の説明
                lb = row[3].replace('"', "") #下限
                ub = row[4].replace('"', "") #上限
                reaction = re.sub(r'^\s+',"",reaction)
                reaction = re.sub(r'\s+$',"",reaction)
                if flag == "0":
                    continue
                pat = re.compile(r'\s+{0}\s+|\s+{1}\s+'.format(separator_onedirection, separator_reversible))
                reactions = re.split(pat, reaction)
                if output == "debug":
                    print(rid, reaction, group, separator_onedirection, separator_reversible)
                if not len(reactions) == 2:
                    continue
                substrate = reactions[0]
                product = reactions[1]
                substrates = re.split(r'\s+\+\s+', substrate)
                products = re.split(r'\s+\+\s+', product)
                self.reactions[rid] = {}
                self.reactions[rid]["reaction"] = reaction
                self.reactions[rid]["group"] = group
                self.reactions[rid]["lb"] = lb
                self.reactions[rid]["ub"] = ub
                self.reactions[rid]["metabolites"] = {}
                self.reactions[rid]["reactionid"] = reactionid

                reactionid = reactionid + 1
                self.reactionid_array.append(rid)

                for compound in substrates:
                    cps =  re.split(r' +', compound)
                    #
                    # 1.1348 13BDglcn[c]
                    #
                    if re.match(r'^[0-9]+\.*[0-9]*$', cps[0]):
                        compound = cps[1]
                        compound = self.check_metabolitename(compound)
                        self.reactions[rid]["metabolites"][compound] = float(cps[0]) * -1.0
                    #
                    # (1.1348) 13BDglcn[c]
                    #
                    elif re.match(r'^\([0-9]+\.*[0-9]*\)$', cps[0]):
                        compound = cps[1]
                        compound = self.check_metabolitename(compound)
                        temp = str(cps[0])
                        temp = temp.replace('(','')
                        temp = temp.replace(')','')
                        self.reactions[rid]["metabolites"][compound] = float(temp) * -1.0
                    else:
                        compound = self.check_metabolitename(compound)
                        self.reactions[rid]["metabolites"][compound] = -1.0
                    self.metabolites[compound] = {"metaboliteid": 1, "reactions":{}}

                for compound in products:
                    cps =  re.split(r' +', compound)
                    if re.match(r'^[0-9]+\.*[0-9]*$', cps[0]):
                        compound = cps[1]
                        compound = self.check_metabolitename(compound)
                        self.reactions[rid]["metabolites"][compound] = float(cps[0]) * 1.0
                    #
                    # (1.1348) 13BDglcn[c]
                    #
                    elif re.match(r'^\([0-9]+\.*[0-9]*\)$', cps[0]):
                        compound = cps[1]
                        compound = self.check_metabolitename(compound)
                        temp = str(cps[0])
                        temp = temp.replace('(','')
                        temp = temp.replace(')','')
                        self.reactions[rid]["metabolites"][compound] = float(temp) * 1.0
                    else:
                        compound = self.check_metabolitename(compound)
                        self.reactions[rid]["metabolites"][compound] = 1.0
                    self.metabolites[compound] = {"metaboliteid": 1, "reactions":{}}
    def check_metabolitename(self, metid):
        if re.match(r'^[0-9]+', metid):
            metid = ""+metid
        return metid
    def check_reactionname(self, rid):
        if re.match(r'^[0-9]+', rid):
            rid = "R"+rid
        rid = rid.replace('-', "_")		#ID
        return rid
    def solve(self, output = "normal"):
        #化合物名の整理
        self.maboliteid_array = list(sorted(self.metabolites.keys()))
        for i, met in enumerate(self.maboliteid_array):
            self.metabolites[met]["metaboliteid"] = i
        #化合物名の整理
        for i, reaction in enumerate(self.reactionid_array):
            for metabolite in self.reactions[reaction]["metabolites"]:
                self.metabolites[metabolite]["reactions"][reaction] =  self.reactions[reaction]["metabolites"][metabolite]
        #
        # PuLPのモデル構築
        #
        self.problem = pulp.LpProblem('sample', pulp.LpMaximize)
        self.x = []
        x = []
        #
        # 反応定義
        #
        for rid in self.reactionid_array:
            lb= self.reactions[rid]["lb"]
            ub= self.reactions[rid]["ub"]
            if output == "debug":
                print(rid, lb, ub)
            self.x.append(pulp.LpVariable(rid, float(lb), float(ub), pulp.LpContinuous))
        #
        # 目的関数
        #
        coeffs = []
        rids = []
        for optstep in self.optstep:
            reactionid = self.reactions[optstep]["reactionid"]
            coef =  self.optstep[optstep]
            coeffs.append(float(coef))
            rids.append(self.x[reactionid])
            if output == "debug":
                print(coeffs, rids, reactionid)

        self.problem += pulp.lpDot(coeffs, rids)
        #self.problem += pulp.lpSum(coeffs * rids)
        #
        # 制約を追加 反応の制約
        #
        for rid in self.constraint:
            reactionid = self.reactions[rid]["reactionid"]
            value = self.constraint[rid]
            if output == "debug":
                print(rid, reactionid, value)
            self.problem +=  self.x[reactionid] == float(value)

        #
        # 制約を追加 化学量論
        #
        for metabolite in self.maboliteid_array:
            coeffs = []
            rids = []
            for rid in self.metabolites[metabolite]["reactions"]:
                reactionid = self.reactions[rid]["reactionid"]
                coeffs.append(float(self.metabolites[metabolite]["reactions"][rid]))
                rids.append(self.x[reactionid])
            if output == "debug":
                print(metabolite, coeffs, rids)
            if metabolite in self.inconstant_onlyincrease:
                self.problem += pulp.lpDot(coeffs, rids) >= 0
            elif metabolite in self.inconstant:
                #self.problem += pulp.lpDot(coeffs, rids) >= 0
                pass
            else:
                self.problem += pulp.lpDot(coeffs, rids) == 0
        #self.status = self.problem.solve(pulp.GLPK(msg=0))
        self.status = self.problem.solve()

        #
        # PuLPのモデル構築  無駄フラックス最小
        #
        self.problem2 = pulp.LpProblem('sample', pulp.LpMinimize)
        self.x2 = []
        x2 = []
        #
        # 反応定義
        #
        #for rid in self.reactionid_array:
        for i in range(len(self.reactionid_array)):
            rid = str(self.x[i])
            lb= self.reactions[rid]["lb"]
            ub= self.reactions[rid]["ub"]
            if self.x[i].value() == None:
                pass
            elif self.x[i].value() > 0:
                lb = 0.0
            elif self.x[i].value() < 0:
                ub = 0.0
            else:
                pass
            if output == "debug":
                print(rid, lb, ub)
            self.x2.append(pulp.LpVariable(rid, float(lb), float(ub), pulp.LpContinuous))
        #
        # 目的関数
        #
        coeffs = []
        rids = []
        for i in range(len(self.reactionid_array)):
            if self.x[i].value() == None:
                coef = 0.0
            elif self.x[i].value() > 0:
                coef = 1.0
            elif self.x[i].value() < 0:
                coef = -1.0
            else:
                coef = 0.0
            coeffs.append(coef)
            rids.append(self.x2[i])
            if output == "debug":
                print(self.x2[i], coeffs, rids)
        self.problem2 += pulp.lpDot(coeffs, rids)

        #for optstep in self.optstep:
        #    reactionid = self.reactions[optstep]["reactionid"]
        #    coef =  self.optstep[optstep]
        #    coeffs.append(float(coef))
        #    rids.append(self.x2[reactionid])
        #    if output == "debug":
        #        print(coeffs, rids)
        #self.problem2 += pulp.lpDot(coeffs, rids)
        #self.problem += pulp.lpSum(coeffs * rids)
        #
        # 制約を追加 反応の制約
        #
        for rid in self.constraint:
            reactionid = self.reactions[rid]["reactionid"]
            value = self.constraint[rid]
            if output == "debug":
                print(rid, reactionid, value)
            self.problem2 +=  self.x2[reactionid] == float(value)
        for i in range(len(self.reactionid_array)):
            rid = str(self.x[i])
            if rid in self.optstep:
                value = self.x[i].value()
                #print(i, rid, value)
                self.problem2 +=  self.x2[i] == float(value)

        #
        # 制約を追加 化学量論
        #
        for metabolite in self.maboliteid_array:
            coeffs = []
            rids = []
            for rid in self.metabolites[metabolite]["reactions"]:
                reactionid = self.reactions[rid]["reactionid"]
                coeffs.append(float(self.metabolites[metabolite]["reactions"][rid]))
                rids.append(self.x2[reactionid])
            if output == "debug":
                print(metabolite, coeffs, rids)
            if metabolite in self.inconstant_onlyincrease:
                self.problem2 += pulp.lpDot(coeffs, rids) >= 0
            elif metabolite in self.inconstant:
                #self.problem += pulp.lpDot(coeffs, rids) >= 0
                pass
            else:
                self.problem2 += pulp.lpDot(coeffs, rids) == 0
        #self.status2 = self.problem2.solve(pulp.GLPK(msg=0))
        self.status = self.problem2.solve()



        return(pulp.LpStatus[self.status], pulp.value(self.problem.objective))

    def show_result(self, filename = "none"):
        if filename == "none":
            for i in range(len(self.reactionid_array)):
                rid = str(self.x[i])
                value =  self.x2[i].value()
                group = self.reactions[rid]["group"]
                if value == None:
                    pass
                elif not -0.0001 < value <0.0001:
                    print(rid,"\t" ,'{:>9.4f}'.format(value),"\t", self.reactions[rid]["reaction"],"\t", str(group))
        else:
            with open(filename, mode='w') as f:
                for i in range(len(self.reactionid_array)):
                    rid = str(self.x2[i])
                    reaction = self.reactions[rid]["reaction"]
                    lb = self.reactions[rid]["lb"]
                    ub = self.reactions[rid]["ub"]
                    group = self.reactions[rid]["group"]
                    line = rid+"\t" +str(group)+"\t" +str(lb)+"\t" +str(ub)+"\t" +str(self.x2[i].value())+"\t"+"\t"+self.reactions[rid]["reaction"]+"\n"
                    f.writelines(line)

    def add_constraint(self, reaction, value = 0):
        self.constraint[reaction] = value
    def delete_constraint(self, reaction):
        del self.constraint[reaction]
    def deletiongenes(self):
        reactions = []
        for reaction in self.reactionid_array:
            if reaction in self.constraint:
                continue
            if reaction in self.optstep:
                continue
            reactions.append(reaction)
        return(reactions)
    def get_value(self, reaction):
        reactionid = self.reactions[reaction]["reactionid"]

        return(self.x2[reactionid].value())
    def single_gene_deletions(self, target):
        reactions =  self.deletiongenes()
        for reaction in  reactions:
            self.add_constraint(reaction, value = 0)
            status = self.solve()
            value = self.get_value(target)
            print(reaction,"\t" ,value,"\t" ,status[0],"\t" ,status[1])
            self.delete_constraint(reaction)
    def add_optstep(self, reaction, value = 1.0):
        self.optstep[reaction] = value
    def delete_optstep(self, reaction):
        del self.optstep[reaction]
    def clear_optstep(self):
        self.optstep = {}
    def set_boundary(self, reaction, lb, ub):
        self.reactions[reaction]["lb"] = lb
        self.reactions[reaction]["ub"] = ub
    def show_reaction(self, reaction):
        print(reaction,"\t" ,self.get_value(reaction))

    def add_inconstant_onlyincrease(self, reaction):
        if type(reaction) is not str:
            for rid in reaction:
                self.inconstant_onlyincrease[rid] = 1
        else:
            self.inconstant_onlyincrease[reaction] = 1
    def delete_inconstant_onlyincrease(self, reaction):
        if type(reaction) is not str:
            for rid in reaction:
                del self.inconstant_onlyincrease[rid]
        else:
            del self.inconstant_onlyincrease[reaction]


    def add_inconstant(self, reaction):
        if type(reaction) is not str:
            for rid in reaction:
                self.inconstant[rid] = 1
        else:
            self.inconstant[reaction] = 1
    def delete_inconstant(self, reaction):
        if type(reaction) is not str:
            for rid in reaction:
                del self.inconstant[rid]
        else:
            del self.inconstant[reaction]
    def get_metabolites(self):
        return(self.metabolites.keys())

# %% [markdown]
# 初期値の設定

# %%
##################################################################################
#
#    Test code for AraGEM model
#
deffilename = "iMM904_181030aminoacid_def.txt"
modelfilename = "iMM904_181030aminoacid.txt"

model = MetabolicModel(deffilename, modelfilename)
#
#Add optimization reaction
#
#model.add_optstep("iMM904")
#
#Delete optimization reaction
#
#model.delete_optstep("iMM904")
#
#Add constraint
#
model.add_constraint("GLCt1", 10)
model.add_constraint("O2t", 0.1)
model.add_constraint("dummyprotein", 0)
#
#Delete constraint
#
#model.delete_constraint("GLCt1")#photon uptake


#
#optimize
#
status,objective = model.solve()
print("Initial condition", status, objective)
#
#
# Show result in list
#
model.show_result()
#
# Show result of one reaction
#
model.show_reaction("iMM904") # Biomass
model.show_reaction("GLYCt") # Glycerol production
model.show_reaction("ETOHt") # Ethanol production
model.show_reaction("ACt2r") #
model.show_reaction("ACtr") #
model.show_reaction("CO2t") #
#
# Save to result file
#
model.show_result("iMM904Test.txt")
# Out:
# Initial condition Optimal 0.21715174
# iMM904 	    0.2172 	 (1.1348) 13BDglcn[c] + (0.4588) ala-L[c] + (0.046) amp[c] + (0.1607) arg-L[c] + (0.1017) asn-L[c] + (0.2975) asp-L[c] + (59.276) atp[c] + (0.000001) camp[c] + (0.000001) chitin[c] + (0.0447) cmp[c] + (0.000001) coa[c] + (0.0066) cys-L[c] + (0.0036) damp[c] + (0.0024) dcmp[c] + (0.0024) dgmp[c] + (0.0036) dtmp[c] + (0.0007) ergst[c] + (0.000001) fad[c] + (0.1054) gln-L[c] + (0.3018) glu-L[c] + (0.2904) gly[c] + (0.5185) glycogen[c] + (0.046) gmp[c] + (0.000001) gthrd[c] + (59.276) h2o[c] + (0.0663) his-L[c] + (0.1927) ile-L[c] + (0.2964) leu-L[c] + (0.2862) lys-L[c] + (0.8079) mannan[c] + (0.0507) met-L[c] + (0.000001) nad[c] + (0.000006) pa_SC[c] + (0.00006) pc_SC[c] + (0.000045) pe_SC[c] + (0.000001) pheme[m] + (0.1339) phe-L[c] + (0.1647) pro-L[c] + (0.000017) ps_SC[c] + (0.000001) thmtp[c] + (0.000053) ptd1ino_SC[c] + (0.000001) q6[m] + (0.00099) ribflv[c] + (0.1854) ser-L[c] + (0.02) so4[c] + (0.1914) thr-L[c] + (0.000066) triglyc_SC[c] + (0.0234) tre[c] + (0.0284) trp-L[c] + (0.102) tyr-L[c] + (0.0599) ump[c] + (0.2646) val-L[c] + (0.0015) zymst[c] --> (59.276) adp[c] + (58.70001) h[c] + (59.305) pi[c] 	 Biomass
# aa5 	    0.0106 	 met-L[c] --> ddx 	 181029 additional reaction
# HEX1 	   10.0000 	 atp[c] + glc-D[c] --> adp[c] + g6p[c] + h[c] 	 hexokinase (D-glucose:ATP)
# PGI 	    9.6290 	 g6p[c] <==> f6p[c] 	 glucose-6-phosphate isomerase
# PFK_3 	    9.3906 	 atp[c] + s7p[c] --> adp[c] + h[c] + s17bp[c] 	 phosphofructokinase (s7p)
# FBA3 	    9.3906 	 s17bp[c] <==> dhap[c] + e4p[c] 	 Sedoheptulose 1,7-bisphosphate D-glyceraldehyde-3-phosphate-lyase
# TPI 	    8.8720 	 dhap[c] <==> g3p[c] 	 triose-phosphate isomerase
# GAPD 	   18.2085 	 g3p[c] + nad[c] + pi[c] <==> 13dpg[c] + h[c] + nadh[c] 	 glyceraldehyde-3-phosphate dehydrogenase
# PGK 	  -18.2085 	 3pg[c] + atp[c] <==> 13dpg[c] + adp[c] 	 phosphoglycerate kinase
# PGM 	  -18.0741 	 2pg[c] <==> 3pg[c] 	 phosphoglycerate mutase
# ENO 	   18.0741 	 2pg[c] <==> h2o[c] + pep[c] 	 enolase
# PYK 	   17.9593 	 adp[c] + h[c] + pep[c] --> atp[c] + pyr[c] 	 pyruvate kinase
# PYRt2m 	    0.2716 	 h[c] + pyr[c] <==> h[m] + pyr[m] 	 pyruvate mitochondrial transport via proton symport
# PDHm 	    0.1847 	 coa[m] + nad[m] + pyr[m] --> accoa[m] + co2[m] + nadh[m] 	 pyruvate dehydrogenase
# PGL 	    0.0006 	 6pgl[c] + h2o[c] --> 6pgc[c] + h[c] 	 6-phosphogluconolactonase
# GND 	    0.0006 	 6pgc[c] + nadp[c] --> co2[c] + nadph[c] + ru5p-D[c] 	 phosphogluconate dehydrogenase
# RPE 	   -0.0631 	 ru5p-D[c] <==> xu5p-D[c] 	 ribulose 5-phosphate 3-epimerase
# RPI 	   -0.0633 	 r5p[c] <==> ru5p-D[c] 	 ribose-5-phosphate isomerase
# TALA 	   -9.3934 	 g3p[c] + s7p[c] <==> e4p[c] + f6p[c] 	 transaldolase
# TKT1 	   -0.0028 	 r5p[c] + xu5p-D[c] <==> g3p[c] + s7p[c] 	 transketolase
# TKT2 	   -0.0602 	 e4p[c] + xu5p-D[c] <==> f6p[c] + g3p[c] 	 transketolase
# PGMT 	   -0.3641 	 g1p[c] <==> g6p[c] 	 phosphoglucomutase
# PYRDC 	   16.9587 	 h[c] + pyr[c] --> acald[c] + co2[c] 	 pyruvate decarboxylase
# ALCD2ir 	   16.5910 	 acald[c] + h[c] + nadh[c] --> etoh[c] + nad[c] 	 alcohol dehydrogenase, reverse rxn (acetaldehyde -> ethanol)
# ALCD2irm 	    0.0969 	 acald[m] + h[m] + nadh[m] --> etoh[m] + nad[m] 	 alcohol dehydrogenase, reverse rxn (acetaldehyde -> ethanol), mitochondrial
# ALDD2y 	    0.2709 	 acald[c] + h2o[c] + nadp[c] --> ac[c] + (2) h[c] + nadph[c] 	 aldehyde dehydrogenase (acetaldehyde, NADP)
# ACS 	    0.1858 	 ac[c] + atp[c] + coa[c] --> accoa[c] + amp[c] + ppi[c] 	 acetyl-CoA synthetase
# ACSm 	    0.1081 	 ac[m] + atp[m] + coa[m] --> accoa[m] + amp[m] + ppi[m] 	 acetyl-CoA synthetase
# HCITSm 	    0.0621 	 accoa[m] + akg[m] + h2o[m] --> coa[m] + h[m] + hcit[m] 	 homocitrate synthase
# CSm 	    0.2219 	 accoa[m] + h2o[m] + oaa[m] --> cit[m] + coa[m] + h[m] 	 citrate synthase
# ACONT 	    0.2219 	 cit[c] <==> icit[c] 	 aconitase
# ICDHy 	    0.2212 	 icit[c] + nadp[c] --> akg[c] + co2[c] + nadph[c] 	 isocitrate dehydrogenase (NADP)
# FUM 	    0.0482 	 fum[c] + h2o[c] <==> mal-L[c] 	 fumarase
# FUMm 	    0.0340 	 fum[m] + h2o[m] <==> mal-L[m] 	 fumarase, mitochondrial
# MDH 	   -0.1163 	 mal-L[c] + nad[c] <==> h[c] + nadh[c] + oaa[c] 	 malate dehydrogenase
# SUCD1m 	    0.0340 	 fad[m] + succ[m] <==> fadh2[m] + fum[m] 	 succinate dehydrogenase
# SUCD3_u6m 	    0.0007 	 fadh2[m] + q6[m] <==> fad[m] + q6h2[m] 	 succinate dehydrogenase (ubiquinone-6), mitochondrial
# ATPS3m 	    0.2511 	 adp[m] + (3) h[c] + pi[m] --> atp[m] + (2) h[m] + h2o[m] 	 ATP synthase, mitochondrial
# CYOOm 	    0.0879 	 (4) focytc[m] + (6) h[m] + o2[m] --> (4) ficytc[m] + (6) h[c] + (2) h2o[m] 	 cytochrome c oxidase, mitochondrial
# CYOR_u6m 	    0.1758 	 (2) ficytc[m] + (1.5) h[m] + q6h2[m] --> (2) focytc[m] + (1.5) h[c] + q6[m] 	 ubiquinol-6 cytochrome c reductase
# FDNG 	    0.0011 	 for[c] + h[c] + q6[m] --> co2[c] + q6h2[m] 	 formate  dehydrogenase, cytosolic/mitochondrial
# NADH2_u6m 	    0.1500 	 h[m] + nadh[m] + q6[m] --> nad[m] + q6h2[m] 	 NADH dehydrogenase, mitochondrial
# PPA 	    0.9467 	 h2o[c] + ppi[c] --> h[c] + (2) pi[c] 	 inorganic diphosphatase
# PPAm 	    0.1081 	 h2o[m] + ppi[m] --> h[m] + (2) pi[m] 	 inorganic diphosphatase
# O2t 	    0.1000 	 o2[e] <==> o2[c] 	 o2 transport (diffusion)
# CYSTS 	    0.0014 	 hcys-L[c] + ser-L[c] --> cyst-L[c] + h2o[c] 	 cystathionine beta-synthase
# SLFAT 	    0.0231 	 adp[c] + h[c] + so4[c] <==> aps[c] + pi[c] 	 sulfate adenylyltransferase (ADP)
# ADSK 	    0.0231 	 aps[c] + atp[c] --> adp[c] + h[c] + paps[c] 	 adenylyl-sulfate kinase
# PAPSR 	    0.0231 	 paps[c] + trdrd[c] --> (2) h[c] + pap[c] + so3[c] + trdox[c] 	 phosphoadenylyl-sulfate reductase (thioredoxin)
# SULR 	   -0.0231 	 (3) h2o[c] + h2s[c] + (3) nadp[c] <==> (5) h[c] + (3) nadph[c] + so3[c] 	 sulfite reductase (NADPH2)
# BPNT 	    0.0231 	 h2o[c] + pap[c] --> amp[c] + pi[c] 	 3',5'-bisphosphate nucleotidase
# METS 	    0.0257 	 5mthf[c] + hcys-L[c] --> h[c] + met-L[c] + thf[c] 	 methionine synthase
# AHCi 	    0.0041 	 ahcys[c] + h2o[c] --> adn[c] + hcys-L[c] 	 adenosylhomocysteinase
# AHSERL2 	    0.0231 	 achms[c] + h2s[c] --> ac[c] + h[c] + hcys-L[c] 	 O-acetylhomoserine (thiol)-lyase
# CYSTGL 	    0.0014 	 cyst-L[c] + h2o[c] --> 2obut[c] + cys-L[c] + nh4[c] 	 cystathionine g-lyase
# HSERTA 	    0.0231 	 accoa[c] + hom-L[c] <==> achms[c] + coa[c] 	 homoserine O-trans-acetylase
# METAT 	    0.0041 	 atp[c] + h2o[c] + met-L[c] --> amet[c] + pi[c] + ppi[c] 	 methionine adenosyltransferase
# ALATA_L 	   -0.1003 	 akg[c] + ala-L[c] <==> glu-L[c] + pyr[c] 	 L-alanine transaminase
# ASADi 	    0.1050 	 4pasp[c] + h[c] + nadph[c] --> aspsa[c] + nadp[c] + pi[c] 	 aspartate-semialdehyde dehydrogenase, irreversible
# ASNS1 	    0.0221 	 asp-L[c] + atp[c] + gln-L[c] + h2o[c] --> amp[c] + asn-L[c] + glu-L[c] + h[c] + ppi[c] 	 asparagine synthase (glutamine-hydrolysing)
# ASPKi 	    0.1050 	 asp-L[c] + atp[c] --> 4pasp[c] + adp[c] 	 aspartate kinase, irreversible
# ASPTA 	   -0.2973 	 akg[c] + asp-L[c] <==> glu-L[c] + oaa[c] 	 aspartate transaminase
# R13GS 	    0.2464 	 udpg[c] --> 13BDglcn[c] + h[c] + udp[c] 	 1,3-beta-glucan synthase
# GBEZ 	    0.1126 	 14glun[c] --> glycogen[c] + h2o[c] 	 1,4-alpha-glucan branching enzyme
# GLYGS 	    0.1126 	 h2o[c] + udpg[c] --> 14glun[c] + h[c] + udp[c] 	 glycogen (starch) synthase
# TRE6PP 	    0.0051 	 h2o[c] + tre6p[c] --> pi[c] + tre[c] 	 trehalose-phosphatase
# TRE6PS 	    0.0051 	 g6p[c] + udpg[c] --> h[c] + tre6p[c] + udp[c] 	 alpha,alpha-trehalose-phosphate synthase (UDP-forming)
# ICL 	    0.0007 	 icit[c] --> glx[c] + succ[c] 	 Isocitrate lyase
# ME2m 	    0.1986 	 mal-L[m] + nadp[m] --> co2[m] + nadph[m] + pyr[m] 	 malic enzyme (NADP), mitochondrial
# PC 	    0.6355 	 atp[c] + hco3[c] + pyr[c] --> adp[c] + h[c] + oaa[c] + pi[c] 	 pyruvate carboxylase
# ACGKm 	    0.0349 	 acglu[m] + atp[m] --> acg5p[m] + adp[m] 	 acetylglutamate kinase, mitochondrial
# ACOTAim 	    0.0349 	 acg5sa[m] + glu-L[m] --> acorn[m] + akg[m] 	 acteylornithine transaminase, irreversible, mitochondrial
# AGPRim 	    0.0349 	 acg5p[m] + h[m] + nadph[m] --> acg5sa[m] + nadp[m] + pi[m] 	 N-acetyl-g-glutamyl-phosphate reductase, irreversible, mitochondrial
# ARGSL 	    0.0349 	 argsuc[c] <==> arg-L[c] + fum[c] 	 argininosuccinate lyase
# ARGSSr 	    0.0349 	 asp-L[c] + atp[c] + citr-L[c] <==> amp[c] + argsuc[c] + h[c] + ppi[c] 	 argininosuccinate synthase, reversible
# CBPS 	    0.0589 	 (2) atp[c] + gln-L[c] + h2o[c] + hco3[c] --> (2) adp[c] + cbp[c] + glu-L[c] + (2) h[c] + pi[c] 	 carbamoyl-phosphate synthase (glutamine-hydrolysing)
# G5SADr 	    0.0358 	 glu5sa[c] <==> 1pyr5c[c] + h[c] + h2o[c] 	 L-glutamate 5-semialdehyde dehydratase, reversible
# G5SD2 	    0.0358 	 glu5p[c] + h[c] + nadh[c] --> glu5sa[c] + nad[c] + pi[c] 	 glutamate-5-semialdehyde dehydrogenase
# GLU5K 	    0.0358 	 atp[c] + glu-L[c] --> adp[c] + glu5p[c] 	 glutamate 5-kinase
# OCBTi 	    0.0349 	 cbp[c] + orn[c] --> citr-L[c] + h[c] + pi[c] 	 ornithine carbamoyltransferase, irreversible
# ORNTACim 	    0.0349 	 acorn[m] + glu-L[m] --> acglu[m] + orn[m] 	 ornithine transacetylase, irreversible, mitochondrial
# P5CR 	    0.0358 	 1pyr5c[c] + (2) h[c] + nadph[c] --> nadp[c] + pro-L[c] 	 pyrroline-5-carboxylate reductase
# ACACT1m 	    0.0029 	 (2) accoa[m] --> aacoa[m] + coa[m] 	 acetyl-CoA C-acetyltransferase, mitochondrial
# ACCOACr 	    0.0863 	 accoa[c] + atp[c] + hco3[c] <==> adp[c] + h[c] + malcoa[c] + pi[c] 	 acetyl-CoA carboxylase, reversible reaction
# DESAT16 	    0.0021 	 h[c] + nadph[c] + o2[c] + pmtcoa[c] --> (2) h2o[c] + hdcoa[c] + nadp[c] 	 Palmitoyl-CoA desaturase (n-C16:0CoA -> n-C16:1CoA)
# DESAT18 	    0.0040 	 h[c] + nadph[c] + o2[c] + stcoa[c] --> (2) h2o[c] + nadp[c] + odecoa[c] 	 stearoyl-CoA desaturase (n-C18:0CoA -> n-C18:1CoA)
# DESAT18_2 	    0.0011 	 h[c] + nadph[c] + o2[c] + odecoa[c] --> (2) h2o[c] + nadp[c] + ocdycacoa[c] 	 Oleoyl-CoA desaturase (n-C18:1CoA -> n-C18:2CoA)
# FAS100COA 	    0.0122 	 (3) h[c] + malcoa[c] + (2) nadph[c] + occoa[c] --> co2[c] + coa[c] + dcacoa[c] + h2o[c] + (2) nadp[c] 	 fatty acyl-CoA synthase (n-C10:0CoA)
# FAS120COA 	    0.0119 	 dcacoa[c] + (3) h[c] + malcoa[c] + (2) nadph[c] --> co2[c] + coa[c] + ddcacoa[c] + h2o[c] + (2) nadp[c] 	 fatty-acyl-CoA synthase (n-C12:0CoA)
# FAS140COA 	    0.0112 	 ddcacoa[c] + (3) h[c] + malcoa[c] + (2) nadph[c] --> co2[c] + coa[c] + h2o[c] + (2) nadp[c] + tdcoa[c] 	 fatty-acyl-CoA synthase (n-C14:0CoA)
# FAS160COA 	    0.0100 	 (3) h[c] + malcoa[c] + (2) nadph[c] + tdcoa[c] --> co2[c] + coa[c] + h2o[c] + (2) nadp[c] + pmtcoa[c] 	 fatty-acyl-CoA synthase (n-C16:0CoA)
# FAS180COA 	    0.0046 	 (3) h[c] + malcoa[c] + (2) nadph[c] + pmtcoa[c] --> co2[c] + coa[c] + h2o[c] + (2) nadp[c] + stcoa[c] 	 fatty-acyl-CoA synthase (n-C18:0CoA)
# FAS80COA_L 	    0.0122 	 accoa[c] + (9) h[c] + (3) malcoa[c] + (6) nadph[c] --> (3) co2[c] + (3) coa[c] + (3) h2o[c] + (6) nadp[c] + occoa[c] 	 fatty acyl-CoA synthase (n-C8:0CoA), lumped reaction
# MTHFR3 	    0.0257 	 (2) h[c] + mlthf[c] + nadph[c] --> 5mthf[c] + nadp[c] 	 5,10-methylenetetrahydrofolatereductase (NADPH)
# MTHFC 	    0.0574 	 h2o[c] + methf[c] <==> 10fthf[c] + h[c] 	 methenyltetrahydrofolate cyclohydrolase
# MTHFD 	    0.0574 	 mlthf[c] + nadp[c] <==> methf[c] + nadph[c] 	 methylenetetrahydrofolate dehydrogenase (NADP)
# DHFRi 	    0.0008 	 dhf[c] + h[c] + nadph[c] --> nadp[c] + thf[c] 	 dihydrofolate reductase (irreversible)
# MAN1PT 	    0.1754 	 gtp[c] + h[c] + man1p[c] --> gdpmann[c] + ppi[c] 	 mannose-1-phosphate guanylyltransferase
# MAN6PI 	   -0.1754 	 man6p[c] <==> f6p[c] 	 mannose-6-phosphate isomerase
# PMANM 	   -0.1754 	 man1p[c] <==> man6p[c] 	 phosphomannomutase
# GALT 	    0.3641 	 gal1p[c] + h[c] + utp[c] <==> ppi[c] + udpgal[c] 	 galactose-1-phosphate uridylyltransferase
# UGLT 	   -0.3641 	 gal1p[c] + udpg[c] <==> g1p[c] + udpgal[c] 	 UDPglucose--hexose-1-phosphate uridylyltransferase
# GLUSx 	    1.0796 	 akg[c] + gln-L[c] + h[c] + nadh[c] --> (2) glu-L[c] + nad[c] 	 glutamate synthase (NADH2)
# ANS 	    0.0062 	 chor[c] + gln-L[c] --> anth[c] + glu-L[c] + h[c] + pyr[c] 	 anthranilate synthase
# GLNS 	    1.2577 	 atp[c] + glu-L[c] + nh4[c] --> adp[c] + gln-L[c] + h[c] + pi[c] 	 glutamine synthetase
# G3PD1ir 	    0.5186 	 dhap[c] + h[c] + nadh[c] --> glyc3p[c] + nad[c] 	 glycerol-3-phosphate dehydrogenase (NAD)
# G3PT 	    0.5132 	 glyc3p[c] + h2o[c] --> glyc[c] + pi[c] 	 glycerol-3-phosphatase
# TRIGS_SC 	    0.0014 	 (0.01) 12dgr_SC[c] + (0.02) dcacoa[c] + (0.06) ddcacoa[c] + (0.17) hdcoa[c] + (0.09) ocdycacoa[c] + (0.24) odecoa[c] + (0.27) pmtcoa[c] + (0.05) stcoa[c] + (0.1) tdcoa[c] --> coa[c] + (0.01) triglyc_SC[c] 	 triglycerol synthesis
# AGTi 	    0.0007 	 ala-L[c] + glx[c] --> gly[c] + pyr[c] 	 Alanine glyoxylate aminotransferase (irreversible)
# GHMT2r 	    0.0839 	 ser-L[c] + thf[c] <==> gly[c] + h2o[c] + mlthf[c] 	 glycine hydroxymethyltransferase, reversible
# HSDxi 	    0.1050 	 aspsa[c] + h[c] + nadh[c] --> hom-L[c] + nad[c] 	 homoserine dehydrogenase (NADH), irreversible
# HSK 	    0.0820 	 atp[c] + hom-L[c] --> adp[c] + h[c] + phom[c] 	 homoserine kinase
# PGCD 	    0.1344 	 3pg[c] + nad[c] --> 3php[c] + h[c] + nadh[c] 	 phosphoglycerate dehydrogenase
# PSERT 	    0.1344 	 3php[c] + glu-L[c] --> akg[c] + pser-L[c] 	 phosphoserine transaminase
# PSP_L 	    0.1344 	 h2o[c] + pser-L[c] --> pi[c] + ser-L[c] 	 phosphoserine phosphatase (L-serine)
# ATPPRT 	    0.0144 	 atp[c] + prpp[c] --> ppi[c] + prbatp[c] 	 ATP phosphoribosyltransferase
# HISTD 	    0.0144 	 h2o[c] + histd[c] + (2) nad[c] --> (3) h[c] + his-L[c] + (2) nadh[c] 	 histidinol dehydrogenase
# HISTP 	    0.0144 	 h2o[c] + hisp[c] --> histd[c] + pi[c] 	 histidinol-phosphatase
# HSTPT 	    0.0144 	 glu-L[c] + imacp[c] --> akg[c] + hisp[c] 	 histidinol-phosphate transaminase
# IG3PS 	    0.0144 	 gln-L[c] + prlp[c] --> aicar[c] + eig3p[c] + glu-L[c] + h[c] 	 Imidazole-glycerol-3-phosphate synthase
# IGPDH 	    0.0144 	 eig3p[c] --> h2o[c] + imacp[c] 	 imidazoleglycerol-phosphate dehydratase
# PRAMPC 	    0.0144 	 h2o[c] + prbamp[c] --> prfp[c] 	 phosphoribosyl-AMP cyclohydrolase
# PRATPP 	    0.0144 	 h2o[c] + prbatp[c] --> h[c] + ppi[c] + prbamp[c] 	 phosphoribosyl-ATP pyrophosphatase
# PRMICIi 	    0.0144 	 prfp[c] --> prlp[c] 	 1-(5-phosphoribosyl)-5-[(5-phosphoribosylamino)methylideneamino)imidazole-4-carboxamide isomerase (irreversible)
# PRPPS 	    0.0661 	 atp[c] + r5p[c] <==> amp[c] + h[c] + prpp[c] 	 phosphoribosylpyrophosphate synthetase
# ADK1 	    0.4241 	 amp[c] + atp[c] <==> (2) adp[c] 	 adenylate kinase
# ADK1m 	    0.1081 	 amp[m] + atp[m] <==> (2) adp[m] 	 adenylate kinase, mitochondrial
# ADNK1 	    0.0041 	 adn[c] + atp[c] --> adp[c] + amp[c] + h[c] 	 adenosine kinase
# CYTK1 	   -0.0059 	 atp[c] + cmp[c] <==> adp[c] + cdp[c] 	 cytidylate kinase (CMP)
# DADK 	   -0.0008 	 atp[c] + damp[c] <==> adp[c] + dadp[c] 	 deoxyadenylate kinase
# NDPK1 	    0.2013 	 atp[c] + gdp[c] <==> adp[c] + gtp[c] 	 nucleoside-diphosphate kinase (ATP:GDP)
# NDPK2 	    0.3738 	 atp[c] + udp[c] <==> adp[c] + utp[c] 	 nucleoside-diphosphate kinase (ATP:UDP)
# NDPK3 	   -0.0030 	 atp[c] + cdp[c] <==> adp[c] + ctp[c] 	 nucleoside-diphosphate kinase (ATP:CDP)
# NDPK5 	   -0.0005 	 atp[c] + dgdp[c] <==> adp[c] + dgtp[c] 	 nucleoside-diphosphate kinase (ATP:dGDP)
# RNDR1 	    0.0008 	 adp[c] + trdrd[c] --> dadp[c] + h2o[c] + trdox[c] 	 ribonucleoside-diphosphate reductase (ADP)
# RNDR4 	    0.0013 	 trdrd[c] + udp[c] --> dudp[c] + h2o[c] + trdox[c] 	 ribonucleoside-diphosphate reductase (UDP)
# RNTR2 	    0.0005 	 gtp[c] + trdrd[c] --> dgtp[c] + h2o[c] + trdox[c] 	 ribonucleoside-triphosphate reductase (GTP)
# UMPK 	    0.0110 	 atp[c] + ump[c] <==> adp[c] + udp[c] 	 UMP kinase
# URIDK2r 	   -0.0013 	 atp[c] + dump[c] <==> adp[c] + dudp[c] 	 uridylate kinase (dUMP)
# HCO3E 	    0.7808 	 co2[c] + h2o[c] <==> h[c] + hco3[c] 	 HCO3 equilibration reaction
# AGAT_SC 	    0.0054 	 (0.01) 1ag3p_SC[c] + (0.02) dcacoa[c] + (0.06) ddcacoa[c] + (0.17) hdcoa[c] + (0.09) ocdycacoa[c] + (0.24) odecoa[c] + (0.27) pmtcoa[c] + (0.05) stcoa[c] + (0.1) tdcoa[c] --> coa[c] + (0.01) pa_SC[c] 	 1-Acyl-glycerol-3-phosphate acyltransferase, yeast-specific
# DAGPYP_SC 	    0.0014 	 h2o[c] + (0.01) pa_SC[c] --> (0.01) 12dgr_SC[c] + pi[c] 	 diacylglycerol pyrophosphate phosphatase, yeast-specific
# DASYN_SC 	    0.0038 	 ctp[c] + h[c] + (0.01) pa_SC[c] <==> (0.01) cdpdag_SC[c] + ppi[c] 	 CDP-Diacylglycerol synthetase, yeast-specific
# GAT1_SC 	    0.0054 	 (0.02) dcacoa[c] + (0.06) ddcacoa[c] + glyc3p[c] + (0.17) hdcoa[c] + (0.09) ocdycacoa[c] + (0.24) odecoa[c] + (0.27) pmtcoa[c] + (0.05) stcoa[c] + (0.1) tdcoa[c] --> (0.01) 1ag3p_SC[c] + coa[c] 	 glycerol 3-phosphate acyltransferase (glycerol 3-phosphate), yeast-specific
# MFAPS_SC 	    0.0013 	 amet[c] + (0.01) ptdmeeta_SC[c] --> ahcys[c] + h[c] + (0.01) ptd2meeta_SC[c] 	 methylene-fatty-acyl-phospholipid synthase, yeast-specific
# MI1PP 	    0.0012 	 h2o[c] + mi1p-D[c] --> inost[c] + pi[c] 	 myo-inositol 1-phosphatase
# MI1PS 	    0.0012 	 g6p[c] --> mi1p-D[c] 	 myo-Inositol-1-phosphate synthase
# PETOHM_SC 	    0.0013 	 amet[c] + (0.01) pe_SC[c] --> ahcys[c] + h[c] + (0.01) ptdmeeta_SC[c] 	 phosphatidylethanolamine N-methyltransferase, yeast-specific
# PINOS_SC 	    0.0012 	 (0.01) cdpdag_SC[c] + inost[c] --> cmp[c] + h[c] + (0.01) ptd1ino_SC[c] 	 phosphatidylinositol synthase, yeast-specific
# PMETM_SC 	    0.0013 	 amet[c] + (0.01) ptd2meeta_SC[c] --> ahcys[c] + h[c] + (0.01) pc_SC[c] 	 Phosphatidyl-N-methylethanolamine N-methyltransferase, yeast-specific
# PSERDm_SC 	    0.0023 	 h[m] + (0.01) ps_SC[m] --> co2[m] + (0.01) pe_SC[m] 	 phosphatidylserine decarboxylase, yeast-specific, mitochondrial
# PSERS_SC 	    0.0026 	 (0.01) cdpdag_SC[c] + ser-L[c] <==> cmp[c] + h[c] + (0.01) ps_SC[c] 	 phosphatidylserine synthase, yeast-specific
# ADSL1r 	    0.0252 	 dcamp[c] <==> amp[c] + fum[c] 	 adenylsuccinate lyase
# ADSL2r 	    0.0215 	 25aics[c] <==> aicar[c] + fum[c] 	 adenylosuccinate lyase
# ADSS 	    0.0252 	 asp-L[c] + gtp[c] + imp[c] --> dcamp[c] + gdp[c] + (2) h[c] + pi[c] 	 adenylosuccinate synthase
# AICART 	    0.0359 	 10fthf[c] + aicar[c] <==> fprica[c] + thf[c] 	 phosphoribosylaminoimidazolecarboxamide formyltransferase
# AIRCr 	    0.0215 	 air[c] + co2[c] <==> 5aizc[c] + h[c] 	 phosphoribosylaminoimidazole carboxylase
# ASPCT 	    0.0240 	 asp-L[c] + cbp[c] --> cbasp[c] + h[c] + pi[c] 	 aspartate carbamoyltransferase
# CTPS1 	    0.0097 	 atp[c] + nh4[c] + utp[c] --> adp[c] + ctp[c] + (2) h[c] + pi[c] 	 CTP synthase (NH3)
# DCMPDA 	   -0.0005 	 dcmp[c] + h[c] + h2o[c] <==> dump[c] + nh4[c] 	 dCMP deaminase
# DGK1 	   -0.0005 	 atp[c] + dgmp[c] <==> adp[c] + dgdp[c] 	 deoxyguanylate kinase (dGMP:ATP)
# DHORD4i 	    0.0240 	 dhor-S[c] + q6[m] --> orot[c] + q6h2[m] 	 dihydoorotic acid (ubiquinone-6), irreversible
# DHORTS 	   -0.0240 	 dhor-S[c] + h2o[c] <==> cbasp[c] + h[c] 	 dihydroorotase
# GARFTi 	    0.0215 	 10fthf[c] + gar[c] --> fgam[c] + h[c] + thf[c] 	 phosphoribosylglycinamide formyltransferase, irreversible
# GK1 	    0.0007 	 atp[c] + gmp[c] <==> adp[c] + gdp[c] 	 guanylate kinase (GMP:ATP)
# GLUPRT 	    0.0215 	 gln-L[c] + h2o[c] + prpp[c] --> glu-L[c] + ppi[c] + pram[c] 	 glutamine phosphoribosyldiphosphate amidotransferase
# GMPS2 	    0.0107 	 atp[c] + gln-L[c] + h2o[c] + xmp[c] --> amp[c] + glu-L[c] + gmp[c] + (2) h[c] + ppi[c] 	 GMP synthase
# IMPC 	   -0.0359 	 h2o[c] + imp[c] <==> fprica[c] 	 IMP cyclohydrolase
# IMPD 	    0.0107 	 h2o[c] + imp[c] + nad[c] --> h[c] + nadh[c] + xmp[c] 	 IMP dehydrogenase
# OMPDC 	    0.0240 	 h[c] + orot5p[c] --> co2[c] + ump[c] 	 orotidine-5'-phosphate decarboxylase
# ORPT 	   -0.0240 	 orot5p[c] + ppi[c] <==> orot[c] + prpp[c] 	 orotate phosphoribosyltransferase
# PRAGSr 	    0.0215 	 atp[c] + gly[c] + pram[c] <==> adp[c] + gar[c] + h[c] + pi[c] 	 phosphoribosylglycinamide synthase
# PRAIS 	    0.0215 	 atp[c] + fpram[c] --> adp[c] + air[c] + (2) h[c] + pi[c] 	 phosphoribosylaminoimidazole synthase
# PRASCS 	    0.0215 	 5aizc[c] + asp-L[c] + atp[c] <==> 25aics[c] + adp[c] + h[c] + pi[c] 	 phosphoribosylaminoimidazolesuccinocarboxamide synthase
# PRFGS 	    0.0215 	 atp[c] + fgam[c] + gln-L[c] + h2o[c] --> adp[c] + fpram[c] + glu-L[c] + h[c] + pi[c] 	 phosphoribosylformylglycinamidine synthase
# TMDS 	    0.0008 	 dump[c] + mlthf[c] --> dhf[c] + dtmp[c] 	 thymidylate synthase
# TRDR 	    0.0257 	 h[c] + nadph[c] + trdox[c] --> nadp[c] + trdrd[c] 	 thioredoxin reductase (NADPH)
# DB4PS 	    0.0004 	 ru5p-D[c] --> db4p[c] + for[c] + h[c] 	 3,4-Dihydroxy-2-butanone-4-phosphate synthase
# DROPPRy 	    0.0002 	 25dhpp[c] + h[c] + nadph[c] --> 25dthpp[c] + nadp[c] 	 2,5-diamino-6-ribosylamino-4(3H)-pyrimidinone 5'-phosphate reductase (nadph)
# DRTPPD 	    0.0002 	 25dthpp[c] + h[c] + h2o[c] --> 5aprbu[c] + nh4[c] 	 2,5-diamino-6-ribitylamino-4(3H)-pyrimidinone 5'-phosphate deaminase
# GTPCII 	    0.0002 	 gtp[c] + (3) h2o[c] --> 25dhpp[c] + for[c] + (2) h[c] + ppi[c] 	 GTP cyclohydrolase II
# PMDPHT 	    0.0002 	 5aprbu[c] + h2o[c] --> 4r5au[c] + pi[c] 	 pyrimidine phosphatase
# RBFSa 	    0.0004 	 4r5au[c] + db4p[c] --> dmlz[c] + (2) h2o[c] + pi[c] 	 riboflavin synthase
# RBFSb 	    0.0002 	 (2) dmlz[c] --> 4r5au[c] + ribflv[c] 	 riboflavin synthase
# C14STR 	    0.0005 	 44mctr[c] + h[c] + nadph[c] --> 44mzym[c] + nadp[c] 	 C-14 sterol reductase
# C3STDH1 	    0.0005 	 4mzym_int1[c] + nad[c] --> 4mzym_int2[c] + co2[c] + h[c] + nadh[c] 	 C-3 sterol dehydrogenase (4-methylzymosterol)
# C3STDH2 	    0.0005 	 nad[c] + zym_int1[c] --> co2[c] + h[c] + nadh[c] + zym_int2[c] 	 C-3 sterol dehydrogenase (zymosterol)
# C3STKR1 	    0.0005 	 4mzym_int2[c] + h[c] + nadph[c] --> 4mzym[c] + nadp[c] 	 C-3 sterol keto reductase (4-methylzymosterol)
# C3STKR2 	    0.0005 	 h[c] + nadph[c] + zym_int2[c] --> nadp[c] + zymst[c] 	 C-3 sterol keto reductase (zymosterol)
# C4STMO1 	    0.0005 	 44mzym[c] + (3) h[c] + (3) nadph[c] + (3) o2[c] --> 4mzym_int1[c] + (4) h2o[c] + (3) nadp[c] 	 C-4 sterol methyl oxidase (4,4-dimethylzymosterol)
# C4STMO2 	    0.0005 	 4mzym[c] + (3) h[c] + (3) nadph[c] + (3) o2[c] --> (4) h2o[c] + (3) nadp[c] + zym_int1[c] 	 C-4 sterol methyl oxidase (4-methylzymosterol)
# CHLSTI 	    0.0002 	 amet[c] + o2[c] + zymst[c] --> ahcys[c] + ergtetrol[c] + h[c] + (2) h2o[c] 	 cholestenol delta-isomerase, lumped reaction
# DMATT 	    0.0010 	 dmpp[c] + ipdp[c] --> grdp[c] + ppi[c] 	 dimethylallyltranstransferase
# DPMVD 	    0.0029 	 5dpmev[c] + atp[c] --> adp[c] + co2[c] + ipdp[c] + pi[c] 	 diphosphomevalonate decarboxylase
# GRTT 	    0.0010 	 grdp[c] + ipdp[c] --> frdp[c] + ppi[c] 	 geranyltranstransferase
# HMGCOAR 	   -0.0029 	 coa[c] + mev-R[c] + (2) nadp[c] <==> (2) h[c] + hmgcoa[c] + (2) nadph[c] 	 Hydroxymethylglutaryl CoA reductase
# HMGCOASm 	   -0.0029 	 coa[m] + h[m] + hmgcoa[m] <==> aacoa[m] + accoa[m] + h2o[m] 	 Hydroxymethylglutaryl CoA synthase, mitochondrial
# IPDDI 	    0.0010 	 ipdp[c] <==> dmpp[c] 	 isopentenyl-diphosphate D-isomerase
# LNS14DMx 	    0.0005 	 (2) h[c] + lanost[c] + (3) nadh[c] + (3) o2[c] --> 44mctr[c] + for[c] + (4) h2o[c] + (3) nad[c] 	 cytochrome P450 lanosterol 14-alpha-demethylase (NAD)
# LNSTLS 	    0.0005 	 Ssq23epx[c] --> lanost[c] 	 lanosterol synthase
# MEVK2 	    0.0029 	 ctp[c] + mev-R[c] --> 5pmev[c] + cdp[c] + h[c] 	 mevalonate kinase (ctp)
# PMEVK 	    0.0029 	 5pmev[c] + atp[c] --> 5dpmev[c] + adp[c] 	 phosphomevalonate kinase
# SQLS 	    0.0005 	 (2) frdp[c] + h[c] + nadph[c] --> nadp[c] + (2) ppi[c] + sql[c] 	 Squalene synthase
# AASAD2 	    0.0621 	 L2aadp[c] + atp[c] + h[c] + nadh[c] --> L2aadp6sa[c] + amp[c] + nad[c] + ppi[c] 	 L-aminoadipate-semialdehyde dehydrogenase (NADH)
# AATA 	    0.0621 	 2oxoadp[c] + glu-L[c] <==> L2aadp[c] + akg[c] 	 2-aminoadipate transaminase
# HACNHm 	    0.0621 	 b124tc[m] + h2o[m] <==> hicit[m] 	 homoacontinate hydratase, mitochondrial
# HICITDm 	    0.0621 	 hicit[m] + nad[m] <==> h[m] + nadh[m] + oxag[m] 	 homoisocitrate dehydrogenase
# MCITDm 	    0.0621 	 hcit[m] <==> b124tc[m] + h2o[m] 	 2-methylcitrate dehydratase, mitochondrial
# OXAGm 	    0.0621 	 h[m] + oxag[m] <==> 2oxoadp[m] + co2[m] 	 non-enzymatic reaction
# SACCD1 	    0.0621 	 L2aadp6sa[c] + glu-L[c] + h[c] + nadph[c] <==> h2o[c] + nadp[c] + saccrp-L[c] 	 saccharopine dehydrogenase (NADP, L-glutamate forming)
# SACCD2 	    0.0621 	 h2o[c] + nad[c] + saccrp-L[c] <==> akg[c] + h[c] + lys-L[c] + nadh[c] 	 saccharopine dehydrogenase (NAD, L-lysine forming)
# THRD_L 	    0.0404 	 thr-L[c] --> 2obut[c] + nh4[c] 	 L-threonine deaminase
# THRS 	    0.0820 	 h2o[c] + phom[c] --> pi[c] + thr-L[c] 	 threonine synthase
# CO2t 	  -17.2267 	 co2[e] <==> co2[c] 	 CO2 transporter via diffusion
# ETOHt 	   16.6878 	 etoh[c] <==> etoh[e] 	 ethanol reversible transport
# GLCt1 	   10.0000 	 glc-D[e] --> glc-D[c] 	 glucose transport (uniport)
# GLYCt 	    0.5132 	 glyc[c] <==> glyc[e] 	 glycerol transport via channel
# H2Ot 	   -2.6380 	 h2o[e] <==> h2o[c] 	 H2O transport via diffusion
# NH4t 	    1.2259 	 nh4[e] <==> nh4[c] 	 ammonia reversible transport
# PIt2r 	    0.0429 	 h[e] + pi[e] <==> h[c] + pi[c] 	 phosphate reversible transport via symport
# PTRCt3i 	    1.1246 	 h[c] + ptrc[e] --> h[e] + ptrc[c] 	 putrescine transport in via proton antiport, irreversible
# PTRCtex2 	    1.1246 	 ptrc[c] --> ptrc[e] 	 putrescine excretion (cytosol to extracellular)
# SO4ti 	    0.0274 	 so4[e] --> so4[c] 	 sulfate irreversible uniport
# R2DDA7Ptm 	   -0.0574 	 2dda7p[c] <==> 2dda7p[m] 	 2-Dehydro-3-deoxy-D-arabino-heptonate7-phohsphate mitochondrial transport via diffusion
# R2OBUTtm 	    0.0418 	 2obut[c] <==> 2obut[m] 	 2obut transporter (mitochondrial)
# R2OXOADPtim 	    0.0621 	 2oxoadp[m] --> 2oxoadp[c] 	 2-oxoadipate transport out of mitochondria via diffusion
# R3MOBtm 	   -0.1217 	 3mob[c] <==> 3mob[m] 	 3-methyl-2-oxobutanoate transport, diffusion, mitochondrial
# R3MOPtm 	   -0.0146 	 3mop[c] <==> 3mop[m] 	 3-Methyl-2-oxopentanoate transport, diffusion, mitochondrial
# ACALDtm 	   -0.0969 	 acald[m] <==> acald[c] 	 acetaldehyde mitochondrial diffusion
# ACtm 	    0.1081 	 ac[c] <==> ac[m] 	 acetate transport, mitochondrial
# CITtam 	   -0.1645 	 cit[c] + mal-L[m] <==> cit[m] + mal-L[c] 	 citrate transport, mitochondrial
# CITtbm 	   -0.0574 	 cit[c] + pep[m] <==> cit[m] + pep[c] 	 citrate transport, mitochondrial
# CO2tm 	   -0.6113 	 co2[c] <==> co2[m] 	 CO2 transport (diffusion), mitochondrial
# COAtim 	    0.0029 	 coa[c] --> coa[m] 	 CoA transporter (mitochondrial), irreversible
# E4Ptm 	    0.0574 	 e4p[c] <==> e4p[m] 	 D-erythrose 4-phosphate mtiochondrial transport via diffusion
# ETOHtm 	   -0.0969 	 etoh[c] <==> etoh[m] 	 ethanol transport to mitochondria (diffusion)
# FRDcm 	    0.0333 	 fadh2[m] + fum[c] --> fad[m] + succ[c] 	 fumarate reductase, cytosolic/mitochondrial
# GLUt7m 	    0.0970 	 glu-L[c] --> glu-L[m] 	 Glutamate transport (uniporter), mitochondrial
# H2Otm 	   -0.1040 	 h2o[c] <==> h2o[m] 	 H2O transport, mitochondrial
# HMGCOAtm 	   -0.0029 	 hmgcoa[c] <==> hmgcoa[m] 	 Hydroxymethylglutaryl-CoA reversible mitochondrial transport
# ILEtmi 	    0.0273 	 ile-L[m] --> ile-L[c] 	 Isoleucine transport from mitochondria to cytosol
# O2tm 	    0.0879 	 o2[c] <==> o2[m] 	 O2 transport (diffusion)
# OAAt2m 	    0.2219 	 h[c] + oaa[c] <==> h[m] + oaa[m] 	 oxaloacetate transport, mitochondrial
# ORNt3m 	    0.0349 	 h[c] + orn[m] <==> h[m] + orn[c] 	 ornithine mitochondrial transport via proton antiport
# PIt2m 	   -0.0234 	 h[c] + pi[c] <==> h[m] + pi[m] 	 phosphate transporter, mitochondrial
# SUCCtm 	    0.0340 	 pi[m] + succ[c] --> pi[c] + succ[m] 	 succinate transport, mitochondrial
# ANPRT 	    0.0062 	 anth[c] + prpp[c] --> ppi[c] + pran[c] 	 anthranilate phosphoribosyltransferase
# CHORM 	    0.0512 	 chor[c] --> pphn[c] 	 chorismate mutase
# CHORS 	    0.0574 	 3psme[c] --> chor[c] + pi[c] 	 chorismate synthase
# DDPAm 	    0.0574 	 e4p[m] + h2o[m] + pep[m] --> 2dda7p[m] + pi[m] 	 2-deoxy-D-arabino-heptulosonate 7-phosphate synthetase, mitochondrial
# DHQS 	    0.0574 	 2dda7p[c] --> 3dhq[c] + pi[c] 	 3-dehydroquinate synthase
# DHQTi 	    0.0574 	 3dhq[c] --> 3dhsk[c] + h2o[c] 	 3-dehydroquinate dehydratase, irreversible
# IGPS 	    0.0062 	 2cpr5p[c] + h[c] --> 3ig3p[c] + co2[c] + h2o[c] 	 indole-3-glycerol-phosphate synthase
# PHETA1 	   -0.0291 	 akg[c] + phe-L[c] <==> glu-L[c] + phpyr[c] 	 phenylalanine transaminase
# PPND2 	    0.0221 	 nadp[c] + pphn[c] --> 34hpp[c] + co2[c] + nadph[c] 	 prephenate dehydrogenase (NADP)
# PPNDH 	    0.0291 	 h[c] + pphn[c] --> co2[c] + h2o[c] + phpyr[c] 	 prephenate dehydratase
# PRAIi 	    0.0062 	 pran[c] --> 2cpr5p[c] 	 phosphoribosylanthranilate isomerase (irreversible)
# PSCVTi 	    0.0574 	 pep[c] + skm5p[c] --> 3psme[c] + pi[c] 	 3-phosphoshikimate 1-carboxyvinyltransferase, irreversible
# SHK3D 	    0.0574 	 3dhsk[c] + h[c] + nadph[c] --> nadp[c] + skm[c] 	 shikimate dehydrogenase
# SHKK 	    0.0574 	 atp[c] + skm[c] --> adp[c] + h[c] + skm5p[c] 	 shikimate kinase
# TRPS1 	    0.0062 	 3ig3p[c] + ser-L[c] --> g3p[c] + h2o[c] + trp-L[c] 	 tryptophan synthase (indoleglycerol phosphate)
# TYRTAi 	    0.0221 	 34hpp[c] + glu-L[c] --> akg[c] + tyr-L[c] 	 tyrosine transaminase, irreversible
# ACHBSm 	    0.0418 	 2obut[m] + h[m] + pyr[m] --> 2ahbut[m] + co2[m] 	 2-aceto-2-hydroxybutanoate synthase, mitochondrial
# ACLSm 	    0.1218 	 h[m] + (2) pyr[m] --> alac-S[m] + co2[m] 	 acetolactate synthase, mitochondrial
# DHAD1m 	    0.1218 	 23dhmb[m] --> 3mob[m] + h2o[m] 	 dihydroxy-acid dehydratase (2,3-dihydroxy-3-methylbutanoate), mitochondrial
# DHAD2m 	    0.0418 	 23dhmp[m] --> 3mop[m] + h2o[m] 	 dihydroxy-acid dehydratase (2,3-dihydroxy-3-methylpentanoate), mitochondrial
# ILETA 	   -0.0146 	 akg[c] + ile-L[c] <==> 3mop[c] + glu-L[c] 	 isoleucine transaminase
# ILETAm 	   -0.0273 	 akg[m] + ile-L[m] <==> 3mop[m] + glu-L[m] 	 isoleucine transaminase, mitochondrial
# IPMD 	    0.0644 	 3c2hmp[c] + nad[c] --> 3c4mop[c] + h[c] + nadh[c] 	 3-isopropylmalate dehydrogenase
# IPPMIa 	   -0.0644 	 3c2hmp[c] <==> 2ippm[c] + h2o[c] 	 3-isopropylmalate dehydratase
# IPPMIb 	   -0.0644 	 2ippm[c] + h2o[c] <==> 3c3hmp[c] 	 2-isopropylmalate hydratase
# IPPS 	    0.0643 	 3mob[c] + accoa[c] + h2o[c] --> 3c3hmp[c] + coa[c] + h[c] 	 2-isopropylmalate synthase
# KARA1im 	    0.1218 	 alac-S[m] + h[m] + nadph[m] --> 23dhmb[m] + nadp[m] 	 acetohydroxy acid isomeroreductase, mitochondrial
# KARA2im 	    0.0418 	 2ahbut[m] + h[m] + nadph[m] --> 23dhmp[m] + nadp[m] 	 ketol-acid reductoisomerase (2-Aceto-2-hydroxybutanoate), mitochondrial
# LEUTA 	   -0.0644 	 akg[c] + leu-L[c] <==> 4mop[c] + glu-L[c] 	 leucine transaminase
# OMCDC 	    0.0644 	 3c4mop[c] + h[c] --> 4mop[c] + co2[c] 	 2-Oxo-4-methyl-3-carboxypentanoate decarboxylation
# VALTA 	   -0.0575 	 akg[c] + val-L[c] <==> 3mob[c] + glu-L[c] 	 valine transaminase
# G6PDH2er 	    0.0006 	 g6p[r] + nadp[r] --> 6pgl[r] + h[r] + nadph[r] 	 glucose 6-phosphate dehydrogenase, endoplasmic reticulum
# DOLPMMer 	    0.1754 	 dolmanp[r] --> dolp[r] + h[r] + mannan[r] 	 Dolichyl-phosphate-mannose--protein mannosyltransferase, endoplasmic reticular
# DOLPMTcer 	    0.1754 	 dolp[c] + gdpmann[c] --> dolmanp[r] + gdp[c] 	 Dolichyl-phosphate D-mannosyltransferase
# C24STRer 	    0.0002 	 ergtetrol[r] + h[r] + nadph[r] --> ergst[r] + nadp[r] 	 C-s24 sterol reductase, endoplamic reticular
# SQLEr 	    0.0005 	 h[r] + nadph[r] + o2[r] + sql[r] --> Ssq23epx[r] + h2o[r] + nadp[r] 	 Squalene epoxidase, endoplasmic reticular (NADP)
# R6PGLter 	   -0.0006 	 6pgl[c] <==> 6pgl[r] 	 6-phospho-D-glucono-1,5-lactone endoplasmic reticular transport via diffusion
# DOLPt2er 	   -0.1754 	 dolp[c] + h[c] <==> dolp[r] + h[r] 	 dolichol phosphate endoplasmic reticular transport via proton symport
# ERGSTter 	    0.0002 	 ergst[r] <==> ergst[c] 	 ergosterol endoplasmic reticular transport
# ERGTETROLter 	    0.0002 	 ergtetrol[c] <==> ergtetrol[r] 	 Ergosta-5,6,22,24,(28)-tetraen-3beta-ol endoplamic reticular transport
# G6Pter 	    0.0006 	 g6p[c] <==> g6p[r] 	 glucose 6-phosphate endoplasmic reticular transport via diffusion
# H2Oter 	   -0.0005 	 h2o[c] <==> h2o[r] 	 H2O endoplasmic reticulum transport
# MANNANter 	   -0.1754 	 mannan[c] <==> mannan[r] 	 mannan endoplasmic reticulum transport via diffusion
# O2ter 	    0.0005 	 o2[c] <==> o2[r] 	 O2  transport, endoplasmic reticulum
# SQ23EPXter 	    0.0005 	 Ssq23epx[r] <==> Ssq23epx[c] 	 Squalene-2,3-epoxide endoplamic reticular transport
# SQLter 	    0.0005 	 sql[c] <==> sql[r] 	 squalene endoplamic reticular transport
# iMM904 	 0.21715174
# GLYCt 	 0.51322038
# ETOHt 	 16.687826
# ACt2r 	 0.0
# ACtr 	 0.0
# CO2t 	 -17.226659

# %% [markdown]
# 動作確認①

# %%
print("Check aerobic anc anaerobic condition")

model.add_constraint("GLCt1", 10)
for o2i in [0.1, 1.0, 2,5,10]:
    model.add_constraint("O2t", o2i)
    status,objective = model.solve()
    print(o2i, status, objective)
    model.show_reaction("iMM904")
    model.show_reaction("GLCt1")
    model.show_reaction("O2t")
    model.show_reaction("CO2t")
    model.show_reaction("ETOHt")
    model.show_reaction("GLYCt")
    model.show_reaction("G6PDH2")
    model.show_reaction("GND")
    model.show_reaction("CSm")
    model.show_reaction("AKGDam")
    model.show_reaction("AKGDbm")
    model.show_reaction("SUCOASm")
model.add_constraint("GLCt1", 0)
model.delete_constraint("O2t")
# Out:
# Check aerobic anc anaerobic condition
# 0.1 Optimal 0.21715174
# iMM904 	 0.21715174
# GLCt1 	 10.0
# O2t 	 0.1
# CO2t 	 -17.226659
# ETOHt 	 16.687826
# GLYCt 	 0.51322038
# G6PDH2 	 0.0
# GND 	 0.00062974005
# CSm 	 0.22192505
# AKGDam 	 0.0
# AKGDbm 	 0.0
# SUCOASm 	 1.7372139e-06
# 1.0 Optimal 0.2642853
# iMM904 	 0.2642853
# GLCt1 	 10.0
# O2t 	 1.0
# CO2t 	 -17.626638
# ETOHt 	 16.437185
# GLYCt 	 0.0
# G6PDH2 	 0.50780484
# GND 	 0.50857126
# CSm 	 0.28302392
# AKGDam 	 0.0
# AKGDbm 	 0.0
# SUCOASm 	 2.1142824e-06
# 2 Optimal 0.29974049
# iMM904 	 0.29974049
# GLCt1 	 10.0
# O2t 	 2.0
# CO2t 	 -17.885468
# ETOHt 	 15.6706
# GLYCt 	 0.0
# G6PDH2 	 0.85136682
# GND 	 0.85223607
# CSm 	 0.51779547
# AKGDam 	 0.19680248
# AKGDbm 	 0.19680248
# SUCOASm 	 -0.19680008
# 5 Optimal 0.3929887
# iMM904 	 0.3929887
# GLCt1 	 10.0
# O2t 	 5.0
# CO2t 	 -18.81285
# ETOHt 	 13.531136
# GLYCt 	 0.0
# G6PDH2 	 0.64066251
# GND 	 0.64180218
# CSm 	 1.6300026
# AKGDam 	 1.2091498
# AKGDbm 	 1.2091498
# SUCOASm 	 -1.2091467
# 10 Optimal 0.54840234
# iMM904 	 0.54840234
# GLCt1 	 10.0
# O2t 	 10.0
# CO2t 	 -20.358256
# ETOHt 	 9.9651358
# GLYCt 	 0.0
# G6PDH2 	 0.28935323
# GND 	 0.29094359
# CSm 	 3.4836137
# AKGDam 	 2.8963236
# AKGDbm 	 2.8963236
# SUCOASm 	 -2.8963192

# %% [markdown]
# 動作確認②

# %%
print("Cost normal")

model.add_constraint("GLCt1", 10)
model.add_constraint("O2t", 0.1)
status,objective = model.solve()
print(o2i, status, objective)
model.show_reaction("iMM904")
model.show_reaction("GLCt1")
model.show_reaction("O2t")
model.show_reaction("Trans1")
model.show_reaction("SO3ti")
normal = model.get_value("iMM904")
print("Cost for H2S synthesis")
model.add_constraint("GLCt1", 10)
model.add_constraint("O2t", 0.1)
model.add_constraint("Trans1", 0.2)
status,objective = model.solve()
print(o2i, status, objective)
model.show_reaction("iMM904")
model.show_reaction("GLCt1")
model.show_reaction("O2t")
model.show_reaction("Trans1")
model.show_reaction("SO3ti")
print("H2S",normal- model.get_value("iMM904"))
model.delete_constraint("Trans1")
# Out:
# Cost normal
# 10 Optimal 0.21715174
# iMM904 	 0.21715174
# GLCt1 	 10.0
# O2t 	 0.1
# Trans1 	 0.0
# SO3ti 	 0.0
# Cost for H2S synthesis
# 10 Optimal 0.21220008
# iMM904 	 0.21220008
# GLCt1 	 10.0
# O2t 	 0.1
# Trans1 	 0.2
# SO3ti 	 0.0
# H2S 0.004951659999999997

# %% [markdown]
# 動作確認③

# %%
print("Cost for SO2 synthesis")
model.add_constraint("GLCt1", 10)
model.add_constraint("O2t", 0.1)
model.add_constraint("SO3ti", 0.2)
status,objective = model.solve()
print(o2i, status, objective)
model.show_reaction("iMM904")
model.show_reaction("GLCt1")
model.show_reaction("O2t")
model.show_reaction("Trans1")
model.show_reaction("SO3ti")
print("SO3",normal- model.get_value("iMM904"))
model.delete_constraint("SO3ti")
# Out:
# Cost for SO2 synthesis
# 10 Optimal 0.21315428
# iMM904 	 0.21315428
# GLCt1 	 10.0
# O2t 	 0.1
# Trans1 	 0.0
# SO3ti 	 0.2
# SO3 0.003997460000000008

# %% [markdown]
# 動作確認④

# %%
print("Check protein as carbon source")

l = [0.01, 0.03, 0.05, 0.07, 0.09, 0.1, 0.5]
reaction_name_list = ["iMM904","GLCt1","O2t","CO2t","alcohol1",
"alcohol2","alcohol3","alcohol4","alcohol5",
"SO4ti","SO3ti","Trans1","Trans2","Trans3",
"Trans4","CYS41","CYS42","CYS31","CYS32",
"CYS43","CYS33","CYS34","ATFS2","cycteindeg2"]

for reaction_name in reaction_name_list:
    model.add_constraint(reaction_name, l[0])
    status,objective = model.solve()
    model.add_constraint(reaction_name, l[1])
    status,objective = model.solve()
    model.add_constraint(reaction_name, l[2])
    status,objective = model.solve()
    model.add_constraint(reaction_name, l[3])
    status,objective = model.solve()
    model.add_constraint(reaction_name, l[4])
    status,objective = model.solve()
    model.add_constraint(reaction_name, l[5])
    status,objective = model.solve()
    model.add_constraint(reaction_name, l[6])
    status,objective = model.solve()
# Out:
# Check protein as carbon source
# -753515.53

# %%
print("Check aerobic anc anaerobic condition")

model.add_constraint("GLCt1", 0)
model.add_constraint("dummyprotein", 0)

for o2i in [0, 0.1, 1.0, 2,5,10]:
    print('■■■■■■■■■■■■■■■■')
    model.add_constraint("O2t", o2i)
    status,objective = model.solve()
    print(o2i, status, objective)
    model.show_reaction("iMM904")
    model.show_reaction("GLCt1")
    model.show_reaction("O2t")
    model.show_reaction("CO2t")
    model.show_reaction("ETOHt")
    model.show_reaction("GLYCt")
    model.show_reaction("G6PDH2")
    model.show_reaction("GND")
    model.show_reaction("CSm")
    model.show_reaction("AKGDam")
    model.show_reaction("AKGDbm")
    model.show_reaction("SUCOASm")

model.add_constraint("GLCt1", 0)
model.delete_constraint("O2t")
# Out:
# Check aerobic anc anaerobic condition
# ■■■■■■■■■■■■■■■■
# 0 Optimal 0.0
# iMM904 	 0.0
# GLCt1 	 0.0
# O2t 	 0.0
# CO2t 	 0.0
# ETOHt 	 0.0
# GLYCt 	 0.0
# G6PDH2 	 0.0
# GND 	 0.0
# CSm 	 0.0
# AKGDam 	 0.0
# AKGDbm 	 0.0
# SUCOASm 	 0.0
# ■■■■■■■■■■■■■■■■
# 0.1 Infeasible -0.0022996122
# iMM904 	 0.0
# GLCt1 	 0.0
# O2t 	 0.1
# CO2t 	 -28.3
# ETOHt 	 0.0
# GLYCt 	 0.0
# G6PDH2 	 0.0
# GND 	 0.0
# CSm 	 0.0
# AKGDam 	 24.4
# AKGDbm 	 24.4
# SUCOASm 	 -24.4
# ■■■■■■■■■■■■■■■■
# 1.0 Infeasible -0.022247739
# iMM904 	 0.0
# GLCt1 	 0.0
# O2t 	 1.0
# CO2t 	 -4.5800632e-13
# ETOHt 	 0.0
# GLYCt 	 0.0
# G6PDH2 	 0.0
# GND 	 0.0
# CSm 	 85.666667
# AKGDam 	 33.444444
# AKGDbm 	 33.444444
# SUCOASm 	 -33.444444
# ■■■■■■■■■■■■■■■■
# 2 Infeasible -0.044813921
# iMM904 	 0.0
# GLCt1 	 0.0
# O2t 	 2.0
# CO2t 	 -92.0
# ETOHt 	 0.0
# GLYCt 	 0.0
# G6PDH2 	 0.0
# GND 	 0.0
# CSm 	 138.0
# AKGDam 	 -138.0
# AKGDbm 	 -138.0
# SUCOASm 	 138.0
# ■■■■■■■■■■■■■■■■
# 5 Infeasible -6.9001134e-14
# iMM904 	 0.0
# GLCt1 	 0.0
# O2t 	 5.0
# CO2t 	 -193.69937
# ETOHt 	 0.0
# GLYCt 	 0.0
# G6PDH2 	 0.0
# GND 	 0.0
# CSm 	 90.399707
# AKGDam 	 0.0
# AKGDbm 	 0.0
# SUCOASm 	 0.0
# ■■■■■■■■■■■■■■■■
# 10 Infeasible -0.22290481
# iMM904 	 0.0
# GLCt1 	 0.0
# O2t 	 10.0
# CO2t 	 0.0
# ETOHt 	 0.0
# GLYCt 	 0.0
# G6PDH2 	 0.0
# GND 	 0.0
# CSm 	 690.0
# AKGDam 	 -230.0
# AKGDbm 	 -230.0
# SUCOASm 	 230.0
